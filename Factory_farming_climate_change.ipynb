# %% [markdown]
# <a href="https://colab.research.google.com/github/atroitskaia/Factory-farming/blob/main/Factory_farming_climate_change.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/DataSchool Project/Climate Change & Farming Data/Emissions_livestock_E_All_Data/Emissions_livestock_E_All_Data.csv')
df.info()

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <cell line: 0>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.info

# %%
df = pd.read_csv('/content/drive/MyDrive/DataSchool Project/Climate Change & Farming Data/Climate_change_Emissions_indicators_E_All_Data/Climate_change_Emissions_indicators_E_All_Data.csv')

# %%
df
# Out:
#         Area Code Area Code (M49)         Area  Item Code Item Code (CPC)  \
# 0               2            '004  Afghanistan       1107          '02132
# 1               2            '004  Afghanistan       1107          '02132
# 2               2            '004  Afghanistan       1107          '02132
# 3               2            '004  Afghanistan       1107          '02132
# 4               2            '004  Afghanistan       1107          '02132
# ...           ...             ...          ...        ...             ...
# 119241       5873            '198         OECD       1048          'F1048
# 119242       5873            '198         OECD       1048          'F1048
# 119243       5873            '198         OECD       1048          'F1048
# 119244       5873            '198         OECD       1048          'F1048
# 119245       5873            '198         OECD       1048          'F1048
#
#          Item  Element Code  \
# 0       Asses          5111
# ...

# %%
df_2 = pd.read_csv('/content/drive/MyDrive/DataSchool Project/Climate Change & Farming Data/Production_Crops_Livestock_E_All_Data/Production_Crops_Livestock_E_All_Data.csv', )
# Out:
# <ipython-input-6-3688373f6aaa>:1: DtypeWarning: Columns (11,14,17,20,23,26,29,32,35,38,41,44,47,50,53,56,59,62,65,68,71,74,77,80,83,86,89,92,95,98,101,104,107,110,113,116,119,122,125,128,131,134,137,140,143,146,149,152,155,158,161,164,167,170,173,176,179,182,185,188,191,194,197) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2 = pd.read_csv('/content/drive/MyDrive/DataSchool Project/Climate Change & Farming Data/Production_Crops_Livestock_E_All_Data/Production_Crops_Livestock_E_All_Data.csv', )

# %%
df_2
# Out:
#        Area Code Area Code (M49)                                     Area  \
# 0              2            '004                              Afghanistan
# 1              2            '004                              Afghanistan
# 2              2            '004                              Afghanistan
# 3              2            '004                              Afghanistan
# 4              2            '004                              Afghanistan
# ...          ...             ...                                      ...
# 78167       5817            '902  Net Food Importing Developing Countries
# 78168       5817            '902  Net Food Importing Developing Countries
# 78169       5817            '902  Net Food Importing Developing Countries
# 78170       5817            '902  Net Food Importing Developing Countries
# 78171       5817            '902  Net Food Importing Developing Countries
#
#        Item Code Item Code (CPC)  \
# 0            221          '01371
# ...

# %%
df_3 = pd.read_csv('/content/drive/MyDrive/DataSchool Project/Climate Change & Farming Data/Environment_Temperature_change_E_All_Data/Environment_Temperature_change_E_All_Data.csv')

# %%
df_3
# Out:
#       Area Code Area Code (M49)         Area  Months Code  \
# 0             2            '004  Afghanistan         7001
# 1             2            '004  Afghanistan         7001
# 2             2            '004  Afghanistan         7002
# 3             2            '004  Afghanistan         7002
# 4             2            '004  Afghanistan         7003
# ...         ...             ...          ...          ...
# 9651       5873            '198         OECD         7018
# 9652       5873            '198         OECD         7019
# 9653       5873            '198         OECD         7019
# 9654       5873            '198         OECD         7020
# 9655       5873            '198         OECD         7020
#
#                    Months  Element Code             Element Unit  Y1961  \
# 0                 January          7271  Temperature change   °c  0.792
# 1                 January          6078  Standard Deviation   °c  1.964
# ...

# %%
df_4 = pd.read_csv('/content/drive/MyDrive/DataSchool Project/Climate Change & Farming Data/CropAllocationFoodFeedFuel_Geotiff/Production_Crops_Livestock_E_Americas.csv')

# %%
df_4
# Out:
#        Area Code Area Code (M49)                                Area  \
# 0              8            '028                 Antigua and Barbuda
# 1              8            '028                 Antigua and Barbuda
# 2              8            '028                 Antigua and Barbuda
# 3              8            '028                 Antigua and Barbuda
# 4              8            '028                 Antigua and Barbuda
# ...          ...             ...                                 ...
# 11118        236            '862  Venezuela (Bolivarian Republic of)
# 11119        236            '862  Venezuela (Bolivarian Republic of)
# 11120        236            '862  Venezuela (Bolivarian Republic of)
# 11121        236            '862  Venezuela (Bolivarian Republic of)
# 11122        236            '862  Venezuela (Bolivarian Republic of)
#
#        Item Code Item Code (CPC)                    Item  Element Code  \
# ...
